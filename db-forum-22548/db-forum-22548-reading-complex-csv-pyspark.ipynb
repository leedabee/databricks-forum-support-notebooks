# %%
# %fs
head '/FileStore/tables/mock_data.csv'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">AFFILIATION,AUTHOR_LIST,COUNTRY
# Yale University.,Yang, Daniel X; Soulos, PaR; Davis, Brtte; Gross, CP; Yu, James B,United States
#
# </div>

# %%
# %fs
head '/FileStore/tables/mock_data_preferred.csv'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&quot;AFFILIATION&quot;,&quot;AUTHOR_LIST&quot;,&quot;COUNTRY&quot;
# &quot;Yale University.&quot;,&quot;Yang, Daniel X; Soulos, PaR; Davis, Brtte; Gross, CP; Yu, James B&quot;,&quot;United States&quot;
#
# </div>

# %%
# the default behavior is that any delimiters found within double quotes will be escaped
df = spark.read.csv('/FileStore/tables/mock_data_preferred.csv', header=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AFFILIATION</th><th>AUTHOR_LIST</th><th>COUNTRY</th></tr></thead><tbody><tr><td>Yale University.</td><td>Yang, Daniel X; Soulos, PaR; Davis, Brtte; Gross, CP; Yu, James B</td><td>United States</td></tr></tbody></table></div>

# %%
from pyspark.sql.types import StringType

# Demonstrate custom function using indexing and a schema assumption
# This assumes that there are 3 columns and AUTHOR_LIST will be the 2nd column

def processRow(row):
    splits = row.split(',')
    result = [splits[0], ', '.join(str(x) for x in splits[1:-1]), splits[-1]]
    return result
  
data = sc.textFile('/FileStore/tables/mock_data.csv')
header = data.first() #extract header
filtered = data.filter(lambda row: row != header) # get just the data
df = filtered.map(lambda row: processRow(row)).toDF(header.split(','))

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AFFILIATION</th><th>AUTHOR_LIST</th><th>COUNTRY</th></tr></thead><tbody><tr><td>Yale University.</td><td>Yang,  Daniel X; Soulos,  PaR; Davis,  Brtte; Gross,  CP; Yu,  James B</td><td>United States</td></tr></tbody></table></div>
